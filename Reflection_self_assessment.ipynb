# %% [markdown]
# <a href="https://colab.research.google.com/github/njaincode/python_for_data_science/blob/main/Reflection_self_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reflection and self-assessment
#
# ---

# %% [markdown]
# ## Self-assessment - Python programming
#
# ### You are going to assess your progress in the programming part of this module, using a ranking system, then you are going to write a set of functions that will allow you to demonstrate your skills, knowledge and understanding.
#
# Reflect on your programming so far in this course.  For each of the criteria below, rank yourself from 1 to 10 using the information below to guide you.  Use the numbers between 1 and 5 and between 5 and 10 to indicate which you are closer to.
#
# 10 = totally confident that you can do this
# 5  = starting to feel confident
# 1  = not confident at all
#
# ---
#
# 1.  Use basic programming concepts and notebooks independently to produce simple coded solutions.
#
# 2.  Code and document inputs, outputs and processes within simple Python programs
#
# 3.  Use variables of a range of types within working Python code
#
# 4.  Explain coded solutions clearly through well-placed comments
#
# 5.  Develop Python coded solutions which process lists of data
#
# 6.  Use meaningful data and function names
#
# 7.  Select and use if statements correctly for given problems
#
# 8.  Select and use appropriate loops correctly for given problems
#
# 9.  Demonstrate clear understanding of selection and repetition by using them appropriately in combination
#
# 10.  Identify and use in-built and imported library functions
#
# 11.  Develop and test the output of user-defined functions
#
# 12.  Demonstrate clear understanding of external functions and custom functions and choose or write them appropriately
#
# 13.  Use Google Colabs and Github together to regularly store copies of code notebooks
#
# 14.  Produce code that is free from obvious errors
#
# 15.  Write neat and readable code (blank lines for spacing, indentation, relevant function naming, relevant variable naming.
#
# 16.  Use basic technical language to explain coded solutions
#
# 17.  Identify obvious errors and look for opportunities to make code faster, more robust or more secure.
#
#
# ## Challenge problem
#
# 1.  Create a list of the criteria.  Each of the criteria should be stored as a string in the list.
# 2.  Create a second list which contains your ranks as a list of numbers.
#
# Give each list a relevant variable name.
#
# Determine the expected output and then write functions to find and display the following:
# *  average ranking
# *  the criteria with the highest ranking (there may be more than one)
# *  the criteria with the lowest ranking (there may be more than one)
# *  the most common ranking level and all the criteria with that ranking
# *  the median ranking and the first criterion that has that ranking (the median should be found by sorting the ranking list from lowest to highest rank and finding the one in the middle.  The criterion will be the first one with that ranking in the original criteria list).
#
# Use text cells to explain what each function does and what the expected output is.  Use a code cell for each function.

# %%
import statistics

def neha_assessment():

  # 1. Create a list of the criteria.  Each of the criteria should be stored as a string in the list.   
  # 2. Create a second list which contains your ranks as a list of numbers.

  list_criteria = {}
  # Populate the list. Can tuple be used here?
  list_criteria.update({0:'Use basic programming concepts and notebooks independently to produce simple coded solutions'})
  list_criteria.update({1:'Code and document inputs, outputs and processes within simple Python programs'})
  list_criteria.update({2: 'Use variables of a range of types within working Python code'})
  list_criteria.update({3:'Explain coded solutions clearly through well-placed comments'})
  list_criteria.update({4: 'Develop Python coded solutions which process lists of data'})
  list_criteria.update({5: 'Use meaningful data and function names'})
  list_criteria.update({6: 'Select and use if statements correctly for given problems'})
  list_criteria.update({7: 'Select and use appropriate loops correctly for given problems'})
  list_criteria.update({8: 'Demonstrate clear understanding of selection and repetition by using them appropriately in combination'})
  list_criteria.update({9: 'Identify and use in-built and imported library functions'})
  list_criteria.update({10: 'Develop and test the output of user-defined functions'})
  list_criteria.update({11: 'Demonstrate clear understanding of external functions and custom functions and choose or write them appropriately'})
  list_criteria.update({12: 'Use Google Colabs and Github together to regularly store copies of code notebooks'})
  list_criteria.update({13: 'Produce code that is free from obvious errors'})
  list_criteria.update({14: 'Write neat and readable code (blank lines for spacing, indentation, relevant function naming, relevant variable naming.'})
  list_criteria.update({15: 'Use basic technical language to explain coded solutions'})
  list_criteria.update({16: 'Identify obvious errors and look for opportunities to make code faster, more robust or more secure.'})
  
  #print(list_criteria[0])

  # Create a second list which contains your ranks as a list of numbers
  my_ass = []
  my_ass.append(6)
  my_ass.append(5)
  my_ass.append(6)
  my_ass.append(8)
  my_ass.append(6)
  my_ass.append(7)
  my_ass.append(7)
  my_ass.append(7)
  my_ass.append(7)
  my_ass.append(3)
  my_ass.append(6)
  my_ass.append(6)
  my_ass.append(8)
  my_ass.append(6)
  my_ass.append(7)
  my_ass.append(7)
  my_ass.append(5)

  #average ranking
  #the criteria with the highest ranking (there may be more than one)
  #the criteria with the lowest ranking (there may be more than one)
  #the most common ranking level and all the criteria with that ranking
  #the median ranking and the first criterion that has that ranking 
  #(the median should be found by sorting the ranking list from lowest to highest rank and finding the one in the middle.
  #The criterion will be the first one with that ranking in the original criteria list).

  # Average ranking
  avg_rank = statistics.mean(my_ass)
  print(f'Average ranking is {avg_rank}')

  # The criteria with the highest ranking
  max_score_index = []
  max_score = max(my_ass)

  print(f'Max score {max_score}')
  num_of_criteria_with_max_score = my_ass.count(max_score)
  print(num_of_criteria_with_max_score)

  # Find the index of crietria with max score
  for i in range(0,17,1):
    if my_ass[i] == max_score:
      max_score_index.append(i)
    
  print(max_score_index)
  for i in range(0,num_of_criteria_with_max_score,1):
    print(f'{list_criteria[max_score_index[i]]} - Score {max_score}')

  # The criteria with the lowest ranking (there may be more than one)
  min_score_index = []
  min_score = min(my_ass)

  print(f'Min score {min_score}')
  num_of_criteria_with_min_score = my_ass.count(min_score)
  print(num_of_criteria_with_min_score)

  # Find the index of crietria with min score
  for i in range(0,17,1):
    if my_ass[i] == min_score:
      min_score_index.append(i)
    
  print(min_score_index)
  for i in range(0,num_of_criteria_with_min_score,1):
    print(f'{list_criteria[min_score_index[i]]} - Score {min_score}')

   # The most common ranking level and all the criteria with that ranking
  print(f'Most common ranking level and all the criteria with that ranking')
  rank_freq = []
  rank_freq_dict = {}
  #most_common_rank = []
  for i in range(1,11):
    rank_freq.append(my_ass.count(i))
    rank_freq_dict.update({i:my_ass.count(i)})
  
  print(f'Dict: {rank_freq_dict}')
  most_common_rank = max(rank_freq)
  most_common_rank_freq = rank_freq.count(most_common_rank)
      
  for i,v in rank_freq_dict.items():
    print(f'Rank: {i} Occurence: {v}')

  print(f'Most common ranking {most_common_rank} with freq {most_common_rank_freq}')
  for i,v in rank_freq_dict.items():
    if v==most_common_rank:
      print(f'Rank {most_common_rank} - {list_criteria[i]}')

  #the median ranking and the first criterion that has that ranking 
  #(the median should be found by sorting the ranking list from lowest to highest rank and finding the one in the middle.
  #The criterion will be the first one with that ranking in the original criteria list)
  rank_freq_tmp = sorted(rank_freq)
  #print(len(rank_freq_tmp)/2)
  rank_median = rank_freq_tmp[int(len(rank_freq_tmp)/2)]
  print(rank_freq_tmp)
  print(f'Median {rank_median}')

  med_cri = 0
  # Find key corresponding to a value
  for i,v in rank_freq_dict.items():
    if v==rank_median:
      print('Match')
      med_cri = i
      break

  print(f'med_cri = {med_cri}')
  print(f'Criteria: {list_criteria[med_cri]}')


neha_assessment()
# Out:
# Average ranking is 6.294117647058823
# Max score 8
# 2
# [3, 12]
# Explain coded solutions clearly through well-placed comments - Score 8
# Use Google Colabs and Github together to regularly store copies of code notebooks - Score 8
# Min score 3
# 1
# [9]
# Identify and use in-built and imported library functions - Score 3
# Most common ranking level and all the criteria with that ranking
# Dict: {1: 0, 2: 0, 3: 1, 4: 0, 5: 2, 6: 6, 7: 6, 8: 2, 9: 0, 10: 0}
# Rank: 1 Occurence: 0
# Rank: 2 Occurence: 0
# Rank: 3 Occurence: 1
# Rank: 4 Occurence: 0
# Rank: 5 Occurence: 2
# Rank: 6 Occurence: 6
# Rank: 7 Occurence: 6
# Rank: 8 Occurence: 2
# Rank: 9 Occurence: 0
# Rank: 10 Occurence: 0
# Most common ranking 6 with freq 2
# Rank 6 - Select and use if statements correctly for given problems
# Rank 6 - Select and use appropriate loops correctly for given problems
# [0, 0, 0, 0, 0, 1, 2, 2, 6, 6]
# Median 1
# Match
# med_cri = 3
# ...

# %%
#
